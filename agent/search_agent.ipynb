# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ############################################################################################# 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# !pip install --upgrade pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 67.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.10.1 requires pandas<2.2.3dev0,>=2.0, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# ...

# %%
import subprocess

process = subprocess.Popen("ollama serve", shell=True)
# !ollama pull hf.co/bartowski/Llama-3.2-3B-Instruct-GGUF:F16
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling b5ebe8fbb5ab...   0% ▕▏    0 B/6.4 GB                  pulling manifest
# pulling b5ebe8fbb5ab...   0% ▕▏    0 B/6.4 GB                  pulling manifest
# pulling b5ebe8fbb5ab...   0% ▕▏ 815 KB/6.4 GB                  pulling manifest
# pulling b5ebe8fbb5ab...   0% ▕▏  15 MB/6.4 GB                  pulling manifest
# pulling b5ebe8fbb5ab...   1% ▕▏  33 MB/6.4 GB                  pulling manifest
# pulling b5ebe8fbb5ab...   1% ▕▏  77 MB/6.4 GB                  pulling manifest
# pulling b5ebe8fbb5ab...   2% ▕▏ 114 MB/6.4 GB                  pulling manifest
# pulling b5ebe8fbb5ab...   2% ▕▏ 119 MB/6.4 GB                  pulling manifest
# pulling b5ebe8fbb5ab...   2% ▕▏ 134 MB/6.4 GB                  pulling manifest
# pulling b5ebe8fbb5ab...   2% ▕▏ 158 MB/6.4 GB                  pulling manifest
# ...

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search = DuckDuckGoSearchRun()

# %%
from langchain_ollama.llms import OllamaLLM

# %%
process = subprocess.Popen("ollama serve", shell=True)
llm = OllamaLLM(model="hf.co/bartowski/Llama-3.2-3B-Instruct-GGUF:F16")

# %%
inn_to_name_query = "Название компании по инн {}"
inn_to_name_prompt = '''Я передам тебе фрагмент текста с названием компании. Выведи только название компани. Не пиши ничего лишнего. Вот фрагмент текста: {}'''

authorized_capital_query = "{} Уставной капитал"
authorized_capital_prompt = '''Я передам тебе фрагмент текста c информацией об уставном капитале компании. Выведи только только число(не слова, а только цифры) - информацию о ее уставном капиталн компании в рублях, при этом переводя миллионы просто в рубли. Напиши ТОЛЬКО цифры - нельзя использовать слова, точки, запятые. Вот фрагмент текста: {}'''

#ceo_birth_date_query = "{} Имя генерального директора"
#ceo_birth_date_prompt = "Я передам тебе фрагмент текста c информацией об дне рождения генерального директора. Выведи только число - год рождения директора. Не пиши ничего лишнего. Вот фрагмент текста: {}"

#employee_count_query = "{} количество сотрудников"
#employee_count_prompt = "Я передам тебе фрагмент текста c информацией в которой может присутствовать число сотрудников в компании. Если в тексте указано число сотрудников комании выведи число сотрудников, если нет - выведи 0. Не пиши ничего лишнего. Вот фрагмент текста: {}"

#income_query = "{} доходы компании"
#income_prompt = "Я передам тебе информацию о компании из интернета, выведи оттуда только число(не слова, а только цифры)  информацию о ее доходах в рублях, при этом переводя миллионы просто в рубли. Напиши ТОЛЬКО цифры - НЕЛЬЗЯ использовать слова, точки, запятые.Вот информация: {}"

address_query = "{} адрес"
address_prompt = "Я передам тебе информацию о компании из интернета, выведи оттуда только название города или области. Не пиши ничего лишнего.Вот информация: {}"

#beneficiary_name_query = "{} бенефициар компании"
#beneficiary_name_prompt = "Я передам тебе информацию о компании из интернета, найди в ней имя бенефициара и выведи его. Не пиши ничего лишнего.Вот информация: {}"

main_okved_query = "{} основной ОКВЭД"
main_okved_prompt = "Я передам тебе информацию о компании из интернета, выведи оттуда только номер основного ОКВЭД. Не пиши ничего лишнего.Вот информация: {}"

#okved_count_query = "{} количество ОКВЭДов"
#okved_count_prompt = "Я передам тебе информацию о компании из интернета, выведи оттуда только количество дополнительных ОКВЭДОВ. Не пиши ничего лишнего.Вот информация: {}"

#tax_system_query = "{} система налогообложения"
#tax_system_prompt = "Я передам тебе информацию из интернета о компании, выведи оттуда какую систему налогообложения использует эта компания. Не пиши ничего лишнего.Вот информация: {}"

#ZSK_query = "{} ЗСК компании"
#ZSK_prompt = "Я передам тебе информацию из интернета о компании, выведи оттуда ЗСК. Не пиши ничего лишнего.Вот информация: {}"

# %%
import time
inn = 7707083893

#beneficiary_name_search_result = search.run(beneficiary_name_query.format(f'{inn}'))
#beneficiary_name= llm.invoke(beneficiary_name_prompt.format(search_result))

#ceo_birth_date_search_result = search.run(ceo_birth_date_query.format(f'{inn}'))
#ceo_birth_date = llm.invoke(ceo_birth_date_prompt.format(search_result))


#okved_count_search_result = search.run(okved_count_query.format(f'{inn}'))
#okved_count = int(llm.invoke(okved_count_prompt.format(search_result)))

#employee_count_search_result = search.run(employee_count_query.format(f'{inn}'))
#employee_count = int(llm.invoke(employee_count_prompt.format(search_result)))

#tax_system_search_result = search.run(tax_system_query.format(f'{inn}'))
#tax_system = str(llm.invoke(tax_system_prompt.format(search_result)))

#ZSK_search_result = search.run(ZSK_query.format(f'{inn}'))
#ZSK = int(llm.invoke(ZSK_prompt.format(search_result)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-337-bf92feffb91d> in <cell line: 36>()
#      34 time.sleep(300)
#      35 income_search_result = search.run(income_query.format(f'{inn}'))
# ---> 36 income = float(llm.invoke(income_prompt.format(search_result)))
#      37
#      38 #ZSK_search_result = search.run(ZSK_query.format(f'{inn}'))
#
# ValueError: could not convert string to float: '7707 608 3893.'

# %%
inn_to_name_search_result = search.run(inn_to_name_query.format(f'{inn}'))
inn_to_name = llm.invoke(inn_to_name_prompt.format(inn_to_name_search_result))
inn_to_name
# Out:
# 'ПАО Сбербанк.'

# %%
authorized_capital_search_result = search.run(authorized_capital_query.format(f'{inn}'))
authorized_capital = float(llm.invoke(authorized_capital_prompt.format(authorized_capital_search_result)).strip())
authorized_capital
# Out:
# 67760844000.0

# %%
address_search_result = search.run(address_query.format(f'{inn}'))
address = llm.invoke(address_prompt.format(address_search_result))
address
# Out:
# 'Москва'

# %%
main_okved_search_result = search.run(main_okved_query.format(f'{inn}'))
main_okved = float(llm.invoke(main_okved_prompt.format(main_okved_search_result)))
main_okved
# Out:
# 64.19

# %%
import pandas as pd
df = pd.read_excel("data.xlsx")
df.tail(5)
# Out:
#                ИНН Дата регистрации  Уставной капитал (руб)  \
# 127464  7722313421       2022-09-21                 12500.0
# 127465  5404221766       2021-10-04                 50000.0
# 127466  9703106470       2022-09-14                 50000.0
# 127467  6163155805       2022-03-24                 10500.0
# 127468  9724067253       2022-02-01                 10000.0
#
#                     Адрес   ФИО Генерального директора  \
# 127464        г. Смоленск  Кунаев Сергей Александрович
# 127465     г. Новосибирск  Семкина Людмила Анатольевна
# 127466          г. Москва                          NaN
# 127467  г. Ростов-на-Дону        РоговойАндрейОлегович
# 127468          г. Москва                          NaN
#
#        Дата рождения Генерального директора             ФИО Бенефициара  \
# 127464                  1982-10-30 00:00:00    Кунаева Галина Сергеевна
# 127465                  1974-03-17 00:00:00                         NaN
# ...

# %%
if employee_count == 0:
  employee_count = None

df.loc[len(df)] = {"ИНН" : inn, "Уставной капитал (руб)" : authorized_capital, 'Адрес' : address, 'Основной ОКВЭД' : main_okved}
df.tail(5)
# Out:
# <ipython-input-493-92a4c622a912>:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df.loc[len(df)] = {"ИНН" : inn, "Уставной капитал (руб)" : authorized_capital, 'Адрес' : address, 'Основной ОКВЭД' : main_okved}
#                ИНН Дата регистрации  Уставной капитал (руб)  \
# 127465  5404221766       2021-10-04            5.000000e+04
# 127466  9703106470       2022-09-14            5.000000e+04
# 127467  6163155805       2022-03-24            1.050000e+04
# 127468  9724067253       2022-02-01            1.000000e+04
# 127469  7707083893              NaT            6.776084e+10
#
#                     Адрес   ФИО Генерального директора  \
# 127465     г. Новосибирск  Семкина Людмила Анатольевна
# ...
